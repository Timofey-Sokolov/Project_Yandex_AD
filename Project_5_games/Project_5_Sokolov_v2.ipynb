# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры.
#
# Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными.
#
# Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# Инструкция по выполнению проекта
#
# Шаг 1. Откройте файл с данными и изучите общую информацию Путь к файлу: /datasets/games.csv. Скачать датасет
#
# Шаг 2. Подготовьте данные
# * Замените названия столбцов (приведите к нижнему регистру);
# * Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# * Обработайте пропуски при необходимости: Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# * Опишите причины, которые могли привести к пропускам;
# * Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
# * Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# Шаг 3. Проведите исследовательский анализ данных.
#
# Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#
# Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам.
#
# За какой характерный срок появляются новые и исчезают старые платформы?
#
# Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
#
# Не учитывайте в работе данные за предыдущие годы.
#
# Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
#
# Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
#
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
#
# Соотнесите выводы с продажами игр на других платформах.
#
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# Шаг 4. Составьте портрет пользователя каждого региона.
#
# Определите для пользователя каждого региона (NA, EU, JP):
# * Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# * Самые популярные жанры (топ-5). Поясните разницу.
# * Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# Шаг 5. Проверьте гипотезы
#
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# * Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Задайте самостоятельно пороговое значение alpha.
#
# Поясните:
# * Как вы сформулировали нулевую и альтернативную гипотезы;
# * Какой критерий применили для проверки гипотез и почему.
#
# Шаг 6. Напишите общий вывод
#
# Оформление: Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown.
#
# Примените форматирование и заголовки.
# Описание данных:
#
# * Name — название игры
# * Platform — платформа
# * Year_of_Release — год выпуска
# * Genre — жанр игры
# * NA_sales — продажи в Северной Америке (миллионы проданных копий)
# * EU_sales — продажи в Европе (миллионы проданных копий)
# * JP_sales — продажи в Японии (миллионы проданных копий)
# * Other_sales — продажи в других странах (миллионы проданных копий)
# * Critic_Score — оценка критиков (максимум 100)
# * User_Score — оценка пользователей (максимум 10)
# * Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
#
# Данные за 2016 год могут быть неполными.
# Как будут проверять мой проект?
# Мы подготовили критерии оценки проекта. Прежде чем решать кейс, внимательно изучите их.
# На что обращают внимание при проверке проекта: Как вы описываете выявленные в данных проблемы?
# Как готовите датасет к анализу?
# Какие строите графики для распределений и как их объясняете?
# Как рассчитываете стандартное отклонение и дисперсию?
# Формулируете ли альтернативную и нулевую гипотезы?
# Какие методы применяете, чтобы их проверить?
# Объясняете результат проверки гипотезы или нет?
# Соблюдаете ли структуру проекта и поддерживаете аккуратность кода?
# Какие выводы делаете?
# Оставляете ли комментарии к шагам?
# Всё необходимое, чтобы выполнить проект, есть в шпаргалках и конспектах прошлых тем.
# Успехов!

# %% [markdown]
# Задача:
#
# Опираясь на данные о продажах игр, оценках пользователей и экспертов, жанров и платформ, необходимо выявить определяющие успешность игры закономерности. Выявить потенциально популярный продукт, подготовить предложеиня интернет-магазину «Стримчик» для планирования рекламных кампании.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats

# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
try:
    df = pd.read_csv(r'C:\Users\Иванов\games.csv')
except:
    df = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# Меняем названия столбцов

# %%
df.columns = df.columns.str.lower()

# %%
display(df.head())
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# * Name — название игры
# * Platform — платформа
# * Year_of_Release — год выпуска
# * Genre — жанр игры
# * NA_sales — продажи в Северной Америке (миллионы проданных копий)
# * EU_sales — продажи в Европе (миллионы проданных копий)
# * JP_sales — продажи в Японии (миллионы проданных копий)
# * Other_sales — продажи в других странах (миллионы проданных копий)
# * Critic_Score — оценка критиков (максимум 100)
# * User_Score — оценка пользователей (максимум 10)
# * Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#        year_of_release      na_sales      eu_sales      jp_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         other_sales  critic_score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
df = df.dropna(subset = ['name'])

# %% [markdown]
# year_of_release Для дальнейшего анализа он необходим. Пропуски в 1.6% данных. Заменить ни медианой не средним не получится.  Удаляем. Меняем тип данных.

# %%
df = df.dropna(subset = ['year_of_release']).reset_index()
df['year_of_release'] = df['year_of_release'].astype('int')

# %% [markdown]
# * NA_sales — продажи в Северной Америке (миллионы проданных копий)
# * EU_sales — продажи в Европе (миллионы проданных копий)
# * JP_sales — продажи в Японии (миллионы проданных копий)
# * Other_sales — продажи в других странах (миллионы проданных копий)
#
# Пропусков нет, тип данных соответствует. Есть нулевые значения. Возможно и такое. Оставляем.

# %% [markdown]
# Critic_Score — оценка критиков (максимум 100).
#
# Есть пропуски, значит критики не оценивали данные игры. Тип данных соответствует. Оставляем.

# %% [markdown]
# User_Score — оценка пользователей (максимум 10)
#
# Есть пропуски и значения tdb. To Be Determined, то есть "Будет определено". Но, не нами.
# Значит, что оценок пользователей для этих игр либо нет, либо их слишком мало. Меняем на NaN. Меняем тип данных.

# %%
df['user_score'] = df['user_score'].replace('tbd', 'NaN').astype('float')

# %% [markdown]
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Есть пропуски. Не все игры проходят через эту организацию. Пропуски заменяем на значение 'noname' для дальнейшего анализа.

# %%
df['rating'] = df['rating'].fillna('noname')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            16444 non-null  int64
#  1   name             16444 non-null  object
#  2   platform         16444 non-null  object
#  3   year_of_release  16444 non-null  int32
#  4   genre            16444 non-null  object
#  5   na_sales         16444 non-null  float64
#  6   eu_sales         16444 non-null  float64
#  7   jp_sales         16444 non-null  float64
#  8   other_sales      16444 non-null  float64
#  9   critic_score     7983 non-null   float64
#  10  user_score       7463 non-null   float64
#  11  rating           16444 non-null  object
# dtypes: float64(6), int32(1), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Было 16715 строк, стало 16444. Удалено 1.6%. Приемлимо.

# %% [markdown]
# Считаем суммарные продажи во всех регионах, заносим их в отдельный столбец.

# %%
df['sum_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']

# %% [markdown]
# Шаг 3. Проведите исследовательский анализ данных.
#
# Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#
# Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам.
#
# За какой характерный срок появляются новые и исчезают старые платформы?
#
# Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
#
# Не учитывайте в работе данные за предыдущие годы.
#
# Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
#
# Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
#
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
#
# Соотнесите выводы с продажами игр на других платформах.
#
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
plt.figure(figsize=(10,5))
plt.title("Количество проданных копий игр за весь период (млн.)")
plt.xlabel("Год")
plt.ylabel("Количество проданных копий")
sns.histplot(x="year_of_release", data=df, bins=72)
plt.show()

# %% [markdown]
# В 2008 и 2009 годах количество выпускаемых компьютерных игр было на пике. А до 1995 их почти не было. Логично, тогда и техника для этого была штучным экземпляром. Странный провал в 2013-2015 год. Возможно это отголоски мирового кризиса 2008-2011 года. Думаю, данные до 1995 года не важны для дальнейшего анализа, их можно не учитывать.

# %%
df_1995 = df.query('year_of_release > 1995')

# %% [markdown]
# Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам.

# %%
df_platform_year = df_1995.pivot_table(index=['platform', 'year_of_release'], values='sum_sales', aggfunc=['sum']).reset_index()

# %%
df_platform_year.columns = ['platform', 'year_of_release', 'sum_sales']

# %%
df_platform_sum = df_platform_year.pivot_table(index=['platform'], values='sum_sales', aggfunc=['sum']).reset_index()

# %%
df_platform_sum.columns = ['platform', 'sum_sales']

# %%
df_platform_sum_top = df_platform_sum.sort_values(by='sum_sales', ascending = False).head(10)

# %%
df_platform_year_top = df_platform_year.query('platform in @df_platform_sum_top.platform')

# %%
plt.figure(figsize=(18,6))
plt.title("Количество проданных копий игр за период 1995-2016 гг (млн.) 10-топ платформами")
plt.xlabel("Год")
plt.ylabel("Количество проданных копий")
sns.lineplot(data=df_platform_year_top, x="year_of_release", y="sum_sales", hue='platform')
plt.show()

# %% [markdown]
# Исходя из представленного графика можно сделать вывод, что сумарное характерное время пребывания платформы на рынке около 7-8 лет, а пик продаж приходится примерно на 3-5 лет.
#
# Так как необходимо построить прогноз на 2017 год, в дальнейшем буду исследовать данные за 2012-2016 года включительно.

# %%
df_2012 = df.query('year_of_release >= 2012')

# %% [markdown]
# Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %%
df_platform_2012 = df_2012.pivot_table(index=['platform', 'year_of_release'], values='sum_sales', aggfunc=['sum']).reset_index()

# %%
df_platform_2012.columns = ['platform', 'year_of_release', 'sum_sales']

# %%
df_platform_2012 = df_platform_2012.sort_values(by='sum_sales', ascending=False)

# %%
plt.figure(figsize=(10,5))
plt.title("Количество проданных копий игр за период 2012-2016 гг (млн.)")
sns.barplot(x='platform', y='sum_sales', data=df_platform_2012, ci=None)
plt.xlabel("Платформа")
plt.ylabel("Количество проданных копий")
plt.show()

# %% [markdown]
# По продажам лидируют платформы PS4, PS3, X360, XOne, 3DS.

# %%
plt.figure(figsize=(18,8))
plt.title("Количество проданных копий игр за период 2012-2016 гг (млн.)")
plt.xlabel("Год")
plt.ylabel("Количество проданных копий")
sns.lineplot(data=df_platform_2012, x="year_of_release", y="sum_sales", hue='platform', linewidth=5)
plt.show()

# %% [markdown]
# PSP, DS	в 2016 году уже не выпускались.
#
# Так как по условию задания данные за 2016 год могут быть неполными, критично 2016 год оценивать не будем.
#
# 3DS показатели падают, но продажи пока есть.
#
# PC показатели падают, но платформа имеет место быть, тем более пользоваться ей будут ещё долго.
#
# PS3	показатели падают стремительно. Есть уже другая версия платформы. Но, пока имеет место быть.
#
# PS4	показатели хорошие.
#
# PSV показатели падают.
#
# Wii продаж очень мало. Есть другая версия платформы.
#
# WiiU показатели падают, но продажи ещё есть.
#
# X360 показатели падают.
#
# XOne показатели падают, но продажи ещё есть.
#
# потенциально прибыльными платформи считаю: PS4, XOne, 3DS, WiiU, PC, PS3. Из них особо выделю PS4 и XOne.

# %% [markdown]
# Дальнейшие расчеты будем проводить только по ним, за период 2012-2016 годов.

# %%
profit_pl = ['PS4', 'XOne', '3DS', 'WiiU', 'PC', 'PS3']

# %%
df_profit = df.query('platform == @profit_pl and year_of_release >= 2012')

# %% [markdown]
# Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
plt.figure(figsize=(12,18))
sns.boxplot(x="platform", y="sum_sales", data=df_profit)
plt.show()

# %% [markdown]
# На платформах PS3, PS4, XOne присутствуют игры, которые покупали очень хорошо (много выбросов). Они выделяются из общей картины (особенно PS4). Они же (совместно с WiiU) имеют более высокое значение продаж. А вот у 3DS и PC более стабильные продукты, но и продажи немного ниже.

# %% [markdown]
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %% [markdown]
# PS4 самая популярная платформа на момент выгрузки данных.

# %%
df_profit_ps4 = df_profit.query('platform == "PS4"')

# %%
sns.scatterplot(x='critic_score', y='sum_sales', data=df_profit_ps4)
plt.show()

# %%
df_profit_ps4['critic_score'].corr(df_profit_ps4['sum_sales'])
# Out:
# 0.40656790206178145

# %% [markdown]
# Между отзывами критиков и продажами прямая зависимость. Чем лучше отзыв, тем больше продаж. Зависимость слабая.

# %%
sns.scatterplot(x='user_score', y='sum_sales', data=df_profit_ps4)
plt.show()

# %%
df_profit_ps4['user_score'].corr(df_profit_ps4['sum_sales'])
# Out:
# -0.03195711020455646

# %% [markdown]
# Между отзывами пользователей и продажами зависимости нет. Видимо перед покупкой продукта клиент больше доверяет профессиональному мнению.

# %% [markdown]
# Соотнесите выводы с продажами игр на других платформах.

# %%
profit_pl = ['XOne', '3DS', 'WiiU', 'PC', 'PS3']
for n in profit_pl:
        table = df_profit.query('platform == @n')
        print(n)
        sns.scatterplot(x='critic_score', y='sum_sales', data=table)
        plt.show()
        print(table['critic_score'].corr(table['sum_sales']))
        sns.scatterplot(x='user_score', y='sum_sales', data=table)
        plt.show()
        print(table['user_score'].corr(table['sum_sales']))
# Out:
# XOne
# 0.4169983280084016
# -0.0689250532827942
# 3DS
# 0.3208028695360786
# 0.1975826341103859
# WiiU
# 0.3483797601201749
# 0.4002190202148619
# PC
# 0.23724324311567896
# -0.12186747630735571
# PS3
# 0.331497259262959
# -0.005143522887113798

# %% [markdown]
# Аналогичная ситуация как и в случае с отдельно выбранной платформой. За исключением платформы WiiU и 3DS (отзывы пользователей). Возможно, пользователи из Японии больше оставляют отзывы на отечественные платформы и больше им доверяют.

# %% [markdown]
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
df_profit_genre = df_profit.pivot_table(index=['genre'], values='sum_sales', aggfunc=['sum','count']).reset_index()

# %%
df_profit_genre.columns = ['genre', 'sum_sales', 'count_sales']

# %%
df_profit_genre = df_profit_genre.sort_values(by='sum_sales', ascending=False)

# %%
plt.figure(figsize=(12,6))
plt.title("выручка продаж игр по жанрам за период 2012-2016 гг (млн.)")
sns.barplot(x='genre', y='sum_sales', data=df_profit_genre, ci=None)
plt.xlabel("жанр")
plt.ylabel("выручка продаж")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.title("среднее количество проданных игр по жанрам за период 2012-2016 гг (млн.)")
sns.barplot(x='genre', y='count_sales', data=df_profit_genre, ci=None)
plt.xlabel("Жанр")
plt.ylabel("среднее количество проданных копий")
plt.show()

# %% [markdown]
# Среди самых прибыльных можно выделить жанры Action, Shooter, Role-Playing, Sports. Самыми невостребованными являются Puzzle.
# По количеству продаж они так-же выделяются но, Shooter продают не так часто как Role-Playing. Можно сделать вывод что Shooter приносит прибыль в основном из-за стоимости продукта. Чего не скажешь о жанре Adventure, продают много но, прибыль меньше чем в общей картине.

# %% [markdown]
# Общий вывод по шагу №3:
#
# * до 1995 компьютерных игр выпускалось очень мало.
# * сумарное характерное время пребывания платформы на рынке около 7-8 лет, а пик продаж приходится примерно на 3-5 лет.
# * потенциально прибыльные платформы 2017 года: PS4, XOne, 3DS, WiiU, PC, PS3.
# * в каждой из этих платформ есть игры, которые покупали заметно лучше общей массы игр.
# * между отзывами критиков и продажами прямая зависимость. Чем лучше отзыв, тем больше продаж. Зависимости между отзывами пользователей и продажами не выявлено.
# * среди самых продаваемых можно выделить жанры Action, Shooter, Role-Playing, Sports. Самыми невостребованными являются Puzzle.

# %% [markdown]
# Шаг 4. Составьте портрет пользователя каждого региона.
#
# Определите для пользователя каждого региона (NA, EU, JP):
# * Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# * Самые популярные жанры (топ-5). Поясните разницу.
# * Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
arr = {"platform":"платформа"}
arr2 = {"NA":'na_sales', "EU":'eu_sales', "JP":'jp_sales'}

for n in arr:
    for r in arr2:
        table = df_profit.pivot_table(index=[n], values=[arr2[r]], aggfunc='sum').reset_index().sort_values(arr2[r], ascending=False)
        plt.figure(figsize=(12,5))
        plt.title(f'{arr[n]} региона {arr2[r]}')
        sns.barplot(x=n, y=arr2[r], data=table, ci=None)
        plt.xlabel(f'{arr[n]}')
        plt.show()
        table['share %'] = np.round((table[arr2[r]]/table[arr2[r]].sum())*100)
        display(table.head())
# Out:
#   platform  na_sales  share %
# 3      PS4    108.74     26.0
# 2      PS3    103.38     25.0
# 5     XOne     93.12     22.0
# 0      3DS     55.31     13.0
# 4     WiiU     38.10      9.0
#   platform  eu_sales  share %
# 3      PS4    141.09     35.0
# 2      PS3    106.86     26.0
# 5     XOne     51.59     13.0
# 0      3DS     42.64     11.0
# 1       PC     37.76      9.0
#   platform  jp_sales  share %
# 0      3DS     87.79     58.0
# 2      PS3     35.29     23.0
# 3      PS4     15.96     10.0
# 4     WiiU     13.01      9.0
# 5     XOne      0.34      0.0

# %% [markdown]
# В Северной Америке и Европе лидирующие положения по платформе занимают PS4, PS3, XOne. 73% долей продаж в Северной Америке и 74% в Европе. Но и наличие других платформ имеет место быть. Чего не скажешь про Японию. Платформами PC и XOne там почти не пользуются, а абсолютным лидером по продажам является 3DS (58% продаж), на втором месте PS3(23%). Японцы явно умеют поддерживать отечественного производителя.

# %%
arr = {"genre":'жанр'}
arr2 = {"NA":'na_sales', "EU":'eu_sales', "JP":'jp_sales'}

for n in arr:
    for r in arr2:
        table = df_profit.pivot_table(index=[n], values=[arr2[r]], aggfunc='sum').reset_index().sort_values(arr2[r], ascending=False)
        plt.figure(figsize=(12,5))
        plt.title(f'{arr[n]} региона {arr2[r]}')
        sns.barplot(x=n, y=arr2[r], data=table, ci=None)
        plt.xlabel(f'{arr[n]}')
        plt.show()

# %% [markdown]
# В Северной Америке и Европе среди самых продаваемых жанров можно выделить жанры Action, Shooter, Sports. Потребители из Японии в отличии от остальных больше предпочитают Role-Playing и Action, а Shooter и Sports их интересует гораздо меньше. Не зря существует термин "Японская ролевая игра" (англ. Japanese Role-Playing Game или JRPG).

# %%
arr = {"rating":'рейтинг'}
arr2 = {"NA":'na_sales', "EU":'eu_sales', "JP":'jp_sales'}

for n in arr:
    for r in arr2:
        table = df_profit.pivot_table(index=[n], values=[arr2[r]], aggfunc='sum').reset_index().sort_values(arr2[r], ascending=False)
        plt.figure(figsize=(12,5))
        plt.title(f'{arr[n]} региона {arr2[r]}')
        sns.barplot(x=n, y=arr2[r], data=table, ci=None)
        plt.xlabel(f'{arr[n]}')
        plt.show()

# %% [markdown]
# В Северной Америке и Европе больше приобретают игры с рейтингом ESRB «M» («Mature») — «Для взрослых». В Японии: «E» («Everyone») — «Для всех» и «T» («Teen») — «Подросткам». Игр без рейтинга гораздо больше чем в Северной Америке и Европе. Видимо это связано с тем, что организация ESRB основанна в Америке и в первую очередь ориентирована на внутренний рынок. Игры с рейтингом «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше» интересуют все регионы почти в равной степени.

# %% [markdown]
# Шаг 5. Проверьте гипотезы
#
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# Задайте самостоятельно пороговое значение alpha.
#
# Поясните:
#
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# Нулевая гипотеза - средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# Альтернативная гипотеза - средние пользовательские рейтинги платформ Xbox One и PC различаются.
#
# Гипотеза двусторонняя. Значение alpha возмем 5%. При проверке будем использовать ttest_ind, т.к. у нас имеется две генеральные совокупности.

# %%
xone = df_profit.query('platform == "XOne"')
pc = df_profit.query('platform == "PC"')
xone = xone.dropna(subset=['user_score'])
pc = pc.dropna(subset=['user_score'])

# %%
alpha = .05
results = scipy.stats.ttest_ind(xone['user_score'], pc['user_score'] ,equal_var=False)
print('p-значение: ', results.pvalue)
if results.pvalue<alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.5489537965134912
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Нулевая гипотеза - средние пользовательские рейтинги жанров Action и Sports одинаковые.
#
# Альтернативная гипотеза - средние пользовательские рейтинги жанров Action и Sports разные.
#
# Гипотеза двусторонняя. Значение alpha возмем 5%. При проверке будем использовать ttest_ind, т.к. у нас имеется две генеральные совокупности.Гипотеза двусторонняя. Значение alpha возмем 5%.

# %%
action = df_profit.query('genre == "Action"')
sports = df_profit.query('genre == "Sports"')
action = action.dropna(subset=['user_score'])
sports = sports.dropna(subset=['user_score'])

# %%
alpha = .05
results = scipy.stats.ttest_ind(action['user_score'], sports['user_score'] ,equal_var=False)
print('p-значение: ', results.pvalue)
if results.pvalue<alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  1.6664626580053579e-15
# Отвергаем нулевую гипотезу

# %% [markdown]
# Итог по шагу 5:
# * средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# * средние пользовательские рейтинги жанров Action и Sports разные.

# %% [markdown]
# Общие выводы по выполнению проекта:
#
# * до 1995 компьютерных игр выпускалось очень мало.
# * сумарное характерное время пребывания платформы на рынке около 7-8 лет, а пик продаж приходится примерно на 3-5 лет.
# * потенциально прибыльные платформы 2017 года: PS4, XOne, 3DS, WiiU, PC, PS3.
# * между отзывами критиков и продажами прямая зависимость. Чем лучше отзыв, тем больше продаж. Зависимости между отзывами пользователей и продажами не выявлено.
# * рынки Северной Америки и Европы отличаются от рынка Японии.
# * В Северной Америке и Европе лидирующие положения по платформе занимают PS4, PS3, XOne. По жанрам - Action, Shooter, Sports. По рейтингу ESRB «M» («Mature») — «Для взрослых».
# * В Японии лидирующие положения по платформе занимают 3DS и PS3. По жанрам - Role-Playing. По рейтингу ESRB - «E» («Everyone») — «Для всех» и «T» («Teen») — «Подросткам».
# * средние пользовательские рейтинги платформ Xbox One и PC в общем сегменте одинаковые.
# * средние пользовательские рейтинги жанров Action и Sports в общем сегменте разные.
#
# Интернет-магазину «Стримчик» для планирования рекламных кампании необходимо учесть лидирующие положения игр с учетом рынков разных стран.
